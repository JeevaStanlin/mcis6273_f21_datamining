# %% [markdown]
# # MCIS6273 Data Mining (Prof. Maull) / Fall 2021 / HW2a
#
# **This assignment is worth up to 5 POINTS to your grade total if you complete it on time.**
#
# | Points <br/>Possible | Due Date | Time Commitment <br/>(estimated) |
# |:---------------:|:--------:|:---------------:|
# | 5 | Friday, October 15 @ Midnight | _up to_ 3 hours |
#
# * **GRADING:** Grading will be aligned with the completeness of the objectives.
#
# * **INDEPENDENT WORK:** Copying, cheating, plagiarism  and academic dishonesty _are not tolerated_ by University or course policy.  Please see the syllabus for the full departmental and University statement on the academic code of honor.
#
# ## OBJECTIVES
#
# * Learn about the new data economy through Ocean Protocol and how Blockchain is fueling innovation in the data space
#
# ## WHAT TO TURN IN
#
# You are being encouraged to turn the assignment in using the provided Jupyter Notebook. To do so, make a
# directory in your Lab environment called `homework/hw2`. Put all of your files in that directory.
# Then zip that directory, rename it with your name as the first part of the filename (e.g. `maull_hw2_files.tar.gz`),
# then download it to your local machine, then upload the .tar.gz to Blackboard.
#
# If you do not know how to do this, please ask, or visit one of the many tutorials out there on the basics of using in
# Linux.
#
# If you choose not to use the provided notebook, you will still need to turn in a `.ipynb` Jupyter Notebook and
# corresponding files according to the instructions in this homework.
#
# ## ASSIGNMENT TASKS
# ### (20%) Learn about the new data economy through Ocean Protocol and how Blockchain is fueling innovation in the data space
#
# You have no doubt heard the phrase “Data is the new oil”, which goes back to 2006, when British data scientist
# and mathematician Clive Humby first coined the phrase.
#
# For an interesing chronology of the phrase over the past 15 years or so, please read the follow Medium.com post:
#
# * [“Data is the New Oil” — A Ludicrous Proposition by Michael Haupt](https://medium.com/project-2030/data-is-the-new-oil-a-ludicrous-proposition-1d91bba4f294)
#
# You can decide for yourself, after some contemplation, whether the “privatization” of data is right or wrong, and
# what one might do about it if they choose to.
#
# Nonetheless, the parallels to oil, and the oil boom at the turn of the 20th century – which profoundly changed
# our relationship with energy and quite literally fueled innovation on a scale that humanity has never seen – are
# interesting. Data, however, is not a finite resource, and the “ownership” of data is quite different than that of oil
# (however controversial that may be). What should be obvious is that producing data and “enriching it” (adding
# “value”) are two different things, and “value” is a term that requires a context.
#
# Nonetheless, we are at an interesting point in the big data, data mining and data science conversation about what
# to do with and how to treat all the data now being produce, particularly as the kind of data that is becoming
# interesting to companies is increasingly personal (i.e. personal health data) and quite possibly being put to use in
# contexts we have no transparency or control over.
# 1
# Blockchain technologies are rapidly become the de facto platforms for data-related transactions, and interesting
# work is being done to use these distributed digital ledgers as data exchange platforms. Even more work is being
# done to bring “data ownership” to a new level on digital marketplaces and the “Internet of Value” or IoV (see also
# [this 2017 writeup on the IoV by Ripple](https://ripple.com/insights/the-internet-of-value-what-it-means-and-how-it-benefits-everyone/)) building the “new data economy”.
# You will be listening to a podcast on this subject involving the [Ocean Protocol](https://oceanprotocol.com/) and its founder Bruce Pon. You
# will listen the almost 43 minute podcast from [The Crypto Conversation](https://bravenewcoin.com/insights/podcasts) Podcast on [Brave New Coin](https://bravenewcoin.com/).
# * “Data is the new oil - Ocean Protocol is building the data economy” - [October 28, 2020 Podcast with Bruce
# Pon](https://bravenewcoin.com/insights/podcasts/data-is-the-new-oil-ocean-protocol-is-building-the-data-economy);
# • download the [mp3 file directly](https://hwcdn.libsyn.com/p/e/2/1/e216c9d24cc00f95/bruce_ocean_final.mp3?c_id=87147389&cs_id=87147389&expiration=1634265272&hwt=4cc31e3bca9c66469b737ce56c322f33).
#
# ##

# %% [markdown]
# § Listen to the entire podcast and answer the questions below:
# 1. What was the original idea that Pon tried in 2013?
#
# **Answer:** The original idea that Pon tried in 2013 was putting original intellectual property or NFTs(Non-Fungible Token) in the bitcoin blockchain. But that did not work because bitcoin isn't good for holding NFTs which was later figured out in 2015.
#
# 2. Who (or what) did Pon say was the “consumer” of Blockchain and big data? How does this relate to “data mining”?
#
# **Answer:** Pon mentions AI(Artificial Intelligence) as the consumer of Blockchain and Big data. When people share data, they share a source of truth, which could be further mined for insights and Pon realized that though they are working on data mining through blockchains and big data, the actual consumer was AI which was the fastest growing industry in the period of 2015 to 2020.
#
# 3. Who does Pon say are the gatekeepers of the current “data economy”? How does Ocean Protocol address this?
#
# **Answer:** Pon says that the internet platforms mainly in US and China like Tencent, Alibaba, baidu, Facebook, Amazon, Netflix, and Google (FANG) , apple, Microsoft, Bloomberg and reuters etc. are the gate keepers of data economy. Data economy is of any economic value that can be created by the use of data, data systems and software. It’s worth trillions as data can be reused and is potentially as valuable as land. So, Ocean Protocol believes that they could build a meaningful framework if the value of the data could be shared amongst people where new internet platforms arise out of data economy where everybody has some power.
#
# 4. How does Pon suggest data might be “securitized” over Ocean Protocol? Use the example he gives directly.
# **Answer:** Pon suggests that data might be “securitized” by turning data streams into value streams. Now, Ocean Protocol has the ability to create ERC20 tokens `(An ERC20 token is a standard used for creating and issuing smart contracts on the Ethereum blockchain. Smart contracts can then be used to create smart property or tokenized assets that people can invest in. ERC stands for "Ethereum request for comment,")` using Ocean Technology. So, by buying a data token we can not only access that data stream, but also trade these tokens in a DEX `(a marketplace that connects crypto buyers and sellers)`.V3 of Ocean Technology solves two issues that people have while sharing data, that is losing control over their data and price for the data. V3 provides users with access control for their data as well as a fair market price for their data.
#
# 5. What are the four landscape users (or targets) of Ocean Protocol?
# **Answer:**
# The four landscape users (or targets) of ocean protocol are
# * 1. Developers
# * 2. Enterprises
# * 3. Users
# * 4. People who are Crypto natives
#
# 6. What example does he give of a liquid dataset that might have tremendous value in a variety of current and future contexts relating to our world?
# **Answer:** The example that Pon gives is Atmospheric data. If we have a temperature data that anybody can access where people are incentivized to keep it fresher and updated even in places that are so remote, we can get a complete view of atmospheric conditions for climate researchers to get a better idea of how global warming is affecting us. Imagine a climate token or carbon token that you can earn for making quality of data about climate or carbon in air better. If the data is being used up, then the data provider will be incentivized. Thus the current financial system is used to work on things that matter to the world such as climate change, global poverty and global health and people can make money out of it.
#
# 7. What does Pon predict the crypto marketplace will look like in 10 years?
#
# **Answer:**
# Pon predicts that in 10 years, there will be probably a couple hundred billion dollar companies built on top of crypto. He also says, Crypto itself will be completely decentralized but companies like coinbase, binance, some nft data companies worth billions probably to the size of the internet is going to happen much faster on a much larger scale because from the very start blockchain has been global, whereas internet started in San Fransisco.
#
#
# 8. After consuming this podcast, please list your reaction to it in a short paragraph of at a minimum of three complete sentences. Address what you already know about crypto and the data economy as well as the things that you learned that were new knowledge. You may also address whether you agree or disagree with Pon’s positions, especially how it relates to Ocean Protocol and cryptocurrencies, in general, becoming a great equalizer. You can also include any personal experiences you have with the technology.
#
# **Answer:**
# This podcast is loaded with information about crypto world. Data economy though exists for several years now, the idea of how it's done is a blind side to still a lot of people. I have very little knowledge about crypto, blockchains and data economy, but this podcast was a great start to learn more about it. I learned lot of new terms and was able to sense what the world is heading towards in terms of financial transactions and how faster it's happening. Though Pon talks about data security through Ocean protocol, I still could not imagine how private data can be traded without affecting privacy.
